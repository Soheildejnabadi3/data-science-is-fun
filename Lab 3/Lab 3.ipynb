# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 5
sns.set_style('darkgrid')

# %%
x = np.linspace(0, 20)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.title('My Graph Title')
plt.xlabel('My x-axis label')
plt.ylabel('My y-axis label')
plt.show()

# %%
plt.plot(x, np.sin(x), label='y=sin(x)')
plt.plot(x, np.cos(x), label='y=cos(x)')
plt.title('Sine and Cosine Functions ')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, np.sin(x))
axes[0].set_title('y=sin(x)')
axes[1].plot(x, np.cos(x))
axes[1].set_title('y=cos(x)')
plt.show()

# %%
x = np.linspace(1, 21)

fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(16, 8))
axes[0][0].plot(x, x**2)
axes[0][1].plot(x, x)
axes[1][0].plot(x, np.log(x))
axes[1][1].plot(x, x**5)
plt.show()

# %%
x = np.linspace(1, 21)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 8))
axes[0][0].plot(x, x**2)
axes[0][1].plot(x, x)
axes[1][0].plot(x, np.log(x))
axes[1][1].plot(x, x**5)
plt.show()

# %%
x = np.linspace(0, 5, 10)
fig, axes = plt.subplots(nrows=1, ncols=3)
axes[0].plot(x, x**2, x, x**4)
axes[0].set_title('default axis range')

axes[1].plot(x, x**2, x, x**4)
axes[1].axis('tight')
axes[1].set_title('tight axis range')

axes[2].plot(x, x**2, x, x**4)
axes[2].set_ylim([0, 35])
axes[2].set_xlim([2, 3])
axes[2].set_title("custom axes range");

plt.show()

# %%
x = np.linspace(0, 5, 11)

plt.plot(x, x+1, color="red", linewidth=0.25)
plt.plot(x, x+2, color="red", linewidth=0.50)
plt.plot(x, x+3, color="red", linewidth=1.00)
plt.plot(x, x+4, color="red", linewidth=2.00)

plt.plot(x, x+5, color="green", lw=3, linestyle='-')
plt.plot(x, x+6, color="green", lw=3, ls='-.')
plt.plot(x, x+7, color="green", lw=3, ls=':')

line, = plt.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) 

plt.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
plt.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
plt.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
plt.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

plt.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
plt.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
plt.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
plt.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
x = np.linspace(0, 5, 11)

plt.plot(x, x+1, color="orange", linewidth=1.25)
plt.plot(x, x+2, color="orange", linewidth=1.50)
plt.plot(x, x+3, color="orange", linewidth=2.00)
plt.plot(x, x+4, color="orange", linewidth=3.00)

plt.plot(x, x+5, color="indigo", lw=3, linestyle='-')
plt.plot(x, x+6, color="indigo", lw=3, ls='-.')
plt.plot(x, x+7, color="indigo", lw=3, ls=':')

line, = plt.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) 

plt.plot(x, x+ 9, color="Violet", lw=3, ls='-', marker='+')
plt.plot(x, x+10, color="Violet", lw=3, ls='--', marker='o')
plt.plot(x, x+11, color="Violet", lw=3, ls='-', marker='s')
plt.plot(x, x+12, color="Violet", lw=3, ls='--', marker='1')

plt.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=4)
plt.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=6)
plt.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
plt.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
pokemon_df = pd.read_csv(filepath_or_buffer='Pokemon.csv')
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
plt.scatter(x=pokemon_df['HP'], y=pokemon_df['Attack'])
plt.xlabel('HP')
plt.ylabel('Attack')
plt.title('HP vs. Attack')
plt.show()

# %%
GOT_df = pd.read_csv(filepath_or_buffer='battles.csv')
GOT_df.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# 1        NaN        NaN  Baratheon  ...         1.0            0.0
# 2        NaN        NaN      Tully  ...         0.0            1.0
# 3        NaN        NaN  Lannister  ...         1.0            1.0
# 4        NaN        NaN  Lannister  ...         1.0            1.0
#
#    attacker_size defender_size  \
# 0        15000.0        4000.0
# 1            NaN         120.0
# 2        15000.0       10000.0
# 3        18000.0       20000.0
# 4         1875.0        6000.0
#
#                                   attacker_commander  \
# 0                                    Jaime Lannister
# 1                                     Gregor Clegane
# 2                       Jaime Lannister, Andros Brax
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                          Robb Stark, Brynden Tully
#
#                                   defender_commander  summer         location  \
# 0                               Clement Piper, Vance     1.0     Golden Tooth
# 1                                   Beric Dondarrion     1.0    Mummer's Ford
# 2                      Edmure Tully, Tytos Blackwood     1.0         Riverrun
# 3  Tywin Lannister, Gregor Clegane, Kevan Lannist...     1.0       Green Fork
# 4                                    Jaime Lannister     1.0  Whispering Wood
#
#             region note
# 0  The Westerlands  NaN
# 1   The Riverlands  NaN
# 2   The Riverlands  NaN
# 3   The Riverlands  NaN
# 4   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
plt.scatter(x=GOT_df['attacker_size'], y=GOT_df['defender_size'])
plt.xlabel('attacker_size')
plt.ylabel('defender_size')
plt.title('attacker vs. defender')
plt.show()

# %%
sns.scatterplot(x=pokemon_df['HP'], y=pokemon_df['Attack'], hue='Generation', data=pokemon_df)
plt.show()

# %%
plt.hist(x=pokemon_df['Attack'])
# Out:
# (array([ 16.,  71., 173., 161., 166., 101.,  65.,  29.,  13.,   5.]),
#  array([  5. ,  23.5,  42. ,  60.5,  79. ,  97.5, 116. , 134.5, 153. ,
#         171.5, 190. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x=pokemon_df['Attack'])
plt.show()

# %%
pokemon_df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
type_1_names = pokemon_df['Type 1'].value_counts().index
type_1_values = pokemon_df['Type 1'].value_counts().values
plt.bar(type_1_names, type_1_values)
plt.title('Type 1 Pokemon value counts')
plt.show()

# %%
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','brown']
patches, texts = plt.pie(type_1_values[:5], colors=colors, shadow=True, startangle=90)
plt.legend(patches, type_1_names[:5])
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','brown']
patches, texts = plt.pie(type_1_values[:5], colors=colors, startangle=90)
plt.legend(patches, type_1_names[:5])
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
x = pokemon_df['Name'][:4]
y1 = pokemon_df['HP'][:4]
y2 = pokemon_df['Attack'][:4]
y3 = pokemon_df['Defense'][:4]

# %%
labels = ["HP ", "Attack", "Defense"]

plt.stackplot(x, y1, y2, y3)
plt.legend(loc='upper left', labels=labels)
plt.xticks(rotation=90)
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, sharey=True)
axes[0].plot(x, y1, 'ko-')
axes[0].set(title='3 subplots', ylabel='HP')

axes[1].plot(x, y2, 'r.-')
axes[1].set(xlabel='Pokemon', ylabel='Attack')

axes[2].plot(x, y3, ':')
axes[2].set(xlabel='Pokemon', ylabel='Defense')

plt.show()

# %%
plt.plot(pokemon_df['Attack'], label='Attack')
plt.plot(pokemon_df['HP'], label='HP')
plt.legend()
plt.show()

# %%
pokemon_df[['HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed']].corr()
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %%
sns.heatmap(pokemon_df[['HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed']].corr())
plt.show()
